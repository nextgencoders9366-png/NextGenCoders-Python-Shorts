# %% [raw]
# from rembg import remove

# %%
from PIL import Image
input_image = Image.open("dog.jpeg")
input_image.thumbnail((200,200))
input_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x133>

# %%
from rembg import remove
output_image = remove(input_image)
output_image.thumbnail((200,200))
output_image
# Out:
# <PIL.Image.Image image mode=RGBA size=200x133>

# %%
import sys
print(sys.version)
# Out:
# 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]

# %%
import PIL
print("Pillow is still working")
# Out:
# Pillow is still working

# %%
import importlib.util
